# %% [markdown]
# # Homework 6
#
# You need to edit this `.ipynb` file by replacing "# Your code", "# Your answer", etc., click "Restart & Run All" in Jupyter Notebook to generate your results, and download it as an `.html` file. Please submit your `.ipynb` and `.html` files (instead of a `.zip` file) on Moodle. If you have questions regarding the homework, please email the TA Saumil Shah (sashah8@ncsu.edu), or attend our office hours.
#
# In this problem, we will observe overfitting by revising the code of "Example: load forecasting" in the "Deep Learning with PyTorch" lecture notes. Then we will employ ridge regularization (L2 regularization) and dropout to mitigate overfitting.
#
# In the following code, we load the data (note that we use a smaller training set, which contains data in 2006 only, so that it is easier to observe overfitting), and define the training and test functions.

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, StandardScaler
df = pd.read_csv('/content/bse_clean (2).csv', parse_dates=['Date'])
df['Day'] = df['Date'].dt.dayofweek
X = np.hstack((OneHotEncoder(sparse_output=False).fit_transform(df[['Hour', 'Month', 'Day']]), df[['T']])).astype('float32')
y = df[['Load']].to_numpy().astype('float32')
train_index = (df['Date'].dt.year == 2006)
test_index = ((df['Date'].dt.year >= 2007) & (df['Date'].dt.year <= 2008))
scaler_X = StandardScaler()
scaler_X.fit(X[train_index])
X = scaler_X.transform(X)
scaler_y = StandardScaler()
scaler_y.fit(y[train_index])
y = scaler_y.transform(y)
X_train = X[train_index]
X_test = X[test_index]
y_train = y[train_index]
y_test = y[test_index]

class LoadDataset(Dataset):
    def __init__(self, X, y):
        self.X, self.y = X, y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

batch_size = 128
train_dataloader = DataLoader(LoadDataset(X_train, y_train), batch_size=batch_size)
test_dataloader = DataLoader(LoadDataset(X_test, y_test), batch_size=batch_size)

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        pred = model(X)
        loss = loss_fn(pred, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f'loss: {loss:f}  [{current:5d}/{size:5d}]')

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, test_mape = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            y_orig = scaler_y.inverse_transform(y)
            pred_orig = scaler_y.inverse_transform(pred)
            test_mape += np.abs((y_orig - pred_orig) / y_orig).sum()
    test_loss /= num_batches
    test_mape /= size
    print(f'Test Error: \n MAPE: {(100 * test_mape):0.2f}%, Avg loss: {test_loss:f}\n')

# %% [markdown]
# In all the problems, you can plot the test loss versus epoch index to better visualize the overfitting and how it is mitigated. But this is optional.
#
# ## Problem 1
#
# In the lecture notes, there are two hidden layers with $64$ and $32$ units, respectively, as shown below. Now change the number of units to $1024$ and $512$, respectively, and run the code. Do not change other parts such as the number of epochs. You should see that the test loss decreases at the beginning, and then increases (though slowly).

# %%
class NeuralNetwork(nn.Module):
     def __init__(self):
         super().__init__()
         self.fc = nn.Sequential(
             nn.Linear(44, 1024),
             nn.ReLU(),
             nn.Linear(1024, 512),
             nn.ReLU(),
             nn.Linear(512, 1)
         )

     def forward(self, x):
         x = self.fc(x)
         return x

model = NeuralNetwork()
loss_fn = nn.MSELoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=1e-3)

epochs = 200
for t in range(epochs):
    print('Epoch', t + 1)
    print('-------------------------------')
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.788004  [    0/ 8760]
# Test Error:
#  MAPE: 8.46%, Avg loss: 0.316012
#
# Epoch 2
# -------------------------------
# loss: 0.211846  [    0/ 8760]
# Test Error:
#  MAPE: 8.10%, Avg loss: 0.315054
#
# Epoch 3
# -------------------------------
# loss: 0.166261  [    0/ 8760]
# Test Error:
#  MAPE: 8.08%, Avg loss: 0.311366
#
# Epoch 4
# -------------------------------
# loss: 0.120823  [    0/ 8760]
# Test Error:
#  MAPE: 7.91%, Avg loss: 0.294236
#
# Epoch 5
# -------------------------------
# loss: 0.087558  [    0/ 8760]
# Test Error:
#  MAPE: 7.65%, Avg loss: 0.273093
#
# Epoch 6
# -------------------------------
# loss: 0.069165  [    0/ 8760]
# Test Error:
#  MAPE: 7.39%, Avg loss: 0.253059
#
# Epoch 7
# -------------------------------
# loss: 0.060840  [    0/ 8760]
# Test Error:
#  MAPE: 7.16%, Avg loss: 0.236675
#
# Epoch 8
# -------------------------------
# loss: 0.058244  [    0/ 8760]
# Test Error:
#  MAPE: 6.97%, Avg loss: 0.223100
#
# Epoch 9
# -------------------------------
# loss: 0.059599  [    0/ 8760]
# Test Error:
#  MAPE: 6.80%, Avg loss: 0.211268
#
# Epoch 10
# -------------------------------
# loss: 0.062984  [    0/ 8760]
# Test Error:
#  MAPE: 6.63%, Avg loss: 0.199817
#
# Epoch 11
# -------------------------------
# loss: 0.062681  [    0/ 8760]
# Test Error:
#  MAPE: 6.43%, Avg loss: 0.188302
#
# Epoch 12
# -------------------------------
# loss: 0.060638  [    0/ 8760]
# Test Error:
#  MAPE: 6.18%, Avg loss: 0.175470
#
# Epoch 13
# -------------------------------
# loss: 0.053677  [    0/ 8760]
# Test Error:
#  MAPE: 5.99%, Avg loss: 0.165440
#
# Epoch 14
# -------------------------------
# loss: 0.052528  [    0/ 8760]
# Test Error:
#  MAPE: 5.81%, Avg loss: 0.156114
#
# Epoch 15
# -------------------------------
# loss: 0.053703  [    0/ 8760]
# Test Error:
#  MAPE: 5.64%, Avg loss: 0.146652
#
# Epoch 16
# -------------------------------
# loss: 0.052228  [    0/ 8760]
# Test Error:
#  MAPE: 5.42%, Avg loss: 0.136324
#
# Epoch 17
# -------------------------------
# loss: 0.051160  [    0/ 8760]
# Test Error:
#  MAPE: 5.27%, Avg loss: 0.128705
#
# Epoch 18
# -------------------------------
# loss: 0.050510  [    0/ 8760]
# Test Error:
#  MAPE: 5.11%, Avg loss: 0.121525
#
# Epoch 19
# -------------------------------
# loss: 0.050765  [    0/ 8760]
# Test Error:
#  MAPE: 5.01%, Avg loss: 0.116769
#
# Epoch 20
# -------------------------------
# loss: 0.050157  [    0/ 8760]
# Test Error:
#  MAPE: 4.89%, Avg loss: 0.111408
#
# Epoch 21
# -------------------------------
# loss: 0.048366  [    0/ 8760]
# Test Error:
#  MAPE: 4.79%, Avg loss: 0.106869
#
# Epoch 22
# -------------------------------
# loss: 0.047651  [    0/ 8760]
# Test Error:
#  MAPE: 4.73%, Avg loss: 0.103542
#
# Epoch 23
# -------------------------------
# loss: 0.046798  [    0/ 8760]
# Test Error:
#  MAPE: 4.66%, Avg loss: 0.100831
#
# Epoch 24
# -------------------------------
# loss: 0.046393  [    0/ 8760]
# Test Error:
#  MAPE: 4.59%, Avg loss: 0.097930
#
# Epoch 25
# -------------------------------
# loss: 0.046348  [    0/ 8760]
# Test Error:
#  MAPE: 4.50%, Avg loss: 0.094413
#
# Epoch 26
# -------------------------------
# loss: 0.046784  [    0/ 8760]
# Test Error:
#  MAPE: 4.48%, Avg loss: 0.093979
#
# Epoch 27
# -------------------------------
# loss: 0.045870  [    0/ 8760]
# Test Error:
#  MAPE: 4.42%, Avg loss: 0.092510
#
# Epoch 28
# -------------------------------
# loss: 0.045167  [    0/ 8760]
# Test Error:
#  MAPE: 4.34%, Avg loss: 0.090072
#
# Epoch 29
# -------------------------------
# loss: 0.044625  [    0/ 8760]
# Test Error:
#  MAPE: 4.26%, Avg loss: 0.087848
#
# Epoch 30
# -------------------------------
# loss: 0.043973  [    0/ 8760]
# Test Error:
#  MAPE: 4.20%, Avg loss: 0.085941
#
# Epoch 31
# -------------------------------
# loss: 0.044855  [    0/ 8760]
# Test Error:
#  MAPE: 4.17%, Avg loss: 0.085021
#
# Epoch 32
# -------------------------------
# loss: 0.043429  [    0/ 8760]
# Test Error:
#  MAPE: 4.10%, Avg loss: 0.082978
#
# Epoch 33
# -------------------------------
# loss: 0.044654  [    0/ 8760]
# Test Error:
#  MAPE: 4.11%, Avg loss: 0.082705
#
# Epoch 34
# -------------------------------
# loss: 0.042366  [    0/ 8760]
# Test Error:
#  MAPE: 4.07%, Avg loss: 0.081580
#
# Epoch 35
# -------------------------------
# loss: 0.042541  [    0/ 8760]
# Test Error:
#  MAPE: 4.05%, Avg loss: 0.081010
#
# Epoch 36
# -------------------------------
# loss: 0.041927  [    0/ 8760]
# Test Error:
#  MAPE: 4.02%, Avg loss: 0.080132
#
# Epoch 37
# -------------------------------
# loss: 0.041150  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.078857
#
# Epoch 38
# -------------------------------
# loss: 0.040415  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.078212
#
# Epoch 39
# -------------------------------
# loss: 0.040295  [    0/ 8760]
# Test Error:
#  MAPE: 3.93%, Avg loss: 0.077621
#
# Epoch 40
# -------------------------------
# loss: 0.039594  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.077168
#
# Epoch 41
# -------------------------------
# loss: 0.039527  [    0/ 8760]
# Test Error:
#  MAPE: 3.90%, Avg loss: 0.076648
#
# Epoch 42
# -------------------------------
# loss: 0.039106  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.076426
#
# Epoch 43
# -------------------------------
# loss: 0.037751  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.075401
#
# Epoch 44
# -------------------------------
# loss: 0.038720  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.076067
#
# Epoch 45
# -------------------------------
# loss: 0.037907  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.077190
#
# Epoch 46
# -------------------------------
# loss: 0.037796  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.077002
#
# Epoch 47
# -------------------------------
# loss: 0.037689  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.075977
#
# Epoch 48
# -------------------------------
# loss: 0.036311  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.074610
#
# Epoch 49
# -------------------------------
# loss: 0.038194  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.073558
#
# Epoch 50
# -------------------------------
# loss: 0.036482  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.074971
#
# Epoch 51
# -------------------------------
# loss: 0.036354  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.077543
#
# Epoch 52
# -------------------------------
# loss: 0.037462  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.078241
#
# Epoch 53
# -------------------------------
# loss: 0.036536  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.077007
#
# Epoch 54
# -------------------------------
# loss: 0.035776  [    0/ 8760]
# Test Error:
#  MAPE: 3.76%, Avg loss: 0.073472
#
# Epoch 55
# -------------------------------
# loss: 0.036119  [    0/ 8760]
# Test Error:
#  MAPE: 3.76%, Avg loss: 0.073853
#
# Epoch 56
# -------------------------------
# loss: 0.036877  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.076583
#
# Epoch 57
# -------------------------------
# loss: 0.035173  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.081018
#
# Epoch 58
# -------------------------------
# loss: 0.035397  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.079638
#
# Epoch 59
# -------------------------------
# loss: 0.034275  [    0/ 8760]
# Test Error:
#  MAPE: 3.74%, Avg loss: 0.074063
#
# Epoch 60
# -------------------------------
# loss: 0.035610  [    0/ 8760]
# Test Error:
#  MAPE: 3.76%, Avg loss: 0.075903
#
# Epoch 61
# -------------------------------
# loss: 0.035510  [    0/ 8760]
# Test Error:
#  MAPE: 3.72%, Avg loss: 0.071716
#
# Epoch 62
# -------------------------------
# loss: 0.034452  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.080818
#
# Epoch 63
# -------------------------------
# loss: 0.034725  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.078091
#
# Epoch 64
# -------------------------------
# loss: 0.035017  [    0/ 8760]
# Test Error:
#  MAPE: 3.65%, Avg loss: 0.069425
#
# Epoch 65
# -------------------------------
# loss: 0.033792  [    0/ 8760]
# Test Error:
#  MAPE: 3.77%, Avg loss: 0.078200
#
# Epoch 66
# -------------------------------
# loss: 0.034526  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.078635
#
# Epoch 67
# -------------------------------
# loss: 0.034502  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.080914
#
# Epoch 68
# -------------------------------
# loss: 0.033346  [    0/ 8760]
# Test Error:
#  MAPE: 3.73%, Avg loss: 0.074564
#
# Epoch 69
# -------------------------------
# loss: 0.036603  [    0/ 8760]
# Test Error:
#  MAPE: 3.75%, Avg loss: 0.076044
#
# Epoch 70
# -------------------------------
# loss: 0.032700  [    0/ 8760]
# Test Error:
#  MAPE: 3.78%, Avg loss: 0.078469
#
# Epoch 71
# -------------------------------
# loss: 0.033555  [    0/ 8760]
# Test Error:
#  MAPE: 3.67%, Avg loss: 0.071510
#
# Epoch 72
# -------------------------------
# loss: 0.032393  [    0/ 8760]
# Test Error:
#  MAPE: 3.78%, Avg loss: 0.079551
#
# Epoch 73
# -------------------------------
# loss: 0.032131  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.080103
#
# Epoch 74
# -------------------------------
# loss: 0.034250  [    0/ 8760]
# Test Error:
#  MAPE: 3.78%, Avg loss: 0.078798
#
# Epoch 75
# -------------------------------
# loss: 0.035518  [    0/ 8760]
# Test Error:
#  MAPE: 3.72%, Avg loss: 0.074945
#
# Epoch 76
# -------------------------------
# loss: 0.032708  [    0/ 8760]
# Test Error:
#  MAPE: 3.78%, Avg loss: 0.078661
#
# Epoch 77
# -------------------------------
# loss: 0.031281  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.080397
#
# Epoch 78
# -------------------------------
# loss: 0.032545  [    0/ 8760]
# Test Error:
#  MAPE: 3.69%, Avg loss: 0.072598
#
# Epoch 79
# -------------------------------
# loss: 0.032176  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.086773
#
# Epoch 80
# -------------------------------
# loss: 0.033131  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.082991
#
# Epoch 81
# -------------------------------
# loss: 0.032768  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.078988
#
# Epoch 82
# -------------------------------
# loss: 0.032499  [    0/ 8760]
# Test Error:
#  MAPE: 3.73%, Avg loss: 0.074328
#
# Epoch 83
# -------------------------------
# loss: 0.030341  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.085719
#
# Epoch 84
# -------------------------------
# loss: 0.033023  [    0/ 8760]
# Test Error:
#  MAPE: 3.75%, Avg loss: 0.075430
#
# Epoch 85
# -------------------------------
# loss: 0.031390  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.083685
#
# Epoch 86
# -------------------------------
# loss: 0.032938  [    0/ 8760]
# Test Error:
#  MAPE: 3.74%, Avg loss: 0.078083
#
# Epoch 87
# -------------------------------
# loss: 0.032145  [    0/ 8760]
# Test Error:
#  MAPE: 3.75%, Avg loss: 0.076450
#
# Epoch 88
# -------------------------------
# loss: 0.031188  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.082508
#
# Epoch 89
# -------------------------------
# loss: 0.032876  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.086260
#
# Epoch 90
# -------------------------------
# loss: 0.031645  [    0/ 8760]
# Test Error:
#  MAPE: 3.67%, Avg loss: 0.072376
#
# Epoch 91
# -------------------------------
# loss: 0.034447  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.088005
#
# Epoch 92
# -------------------------------
# loss: 0.033103  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.081071
#
# Epoch 93
# -------------------------------
# loss: 0.033367  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.079753
#
# Epoch 94
# -------------------------------
# loss: 0.030688  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.081783
#
# Epoch 95
# -------------------------------
# loss: 0.029839  [    0/ 8760]
# Test Error:
#  MAPE: 3.75%, Avg loss: 0.079930
#
# Epoch 96
# -------------------------------
# loss: 0.036495  [    0/ 8760]
# Test Error:
#  MAPE: 3.76%, Avg loss: 0.074329
#
# Epoch 97
# -------------------------------
# loss: 0.033764  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.085573
#
# Epoch 98
# -------------------------------
# loss: 0.031600  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.082132
#
# Epoch 99
# -------------------------------
# loss: 0.032919  [    0/ 8760]
# Test Error:
#  MAPE: 3.75%, Avg loss: 0.077691
#
# Epoch 100
# -------------------------------
# loss: 0.031328  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.081703
#
# Epoch 101
# -------------------------------
# loss: 0.031827  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.083238
#
# Epoch 102
# -------------------------------
# loss: 0.032187  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.083364
#
# Epoch 103
# -------------------------------
# loss: 0.030048  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.083313
#
# Epoch 104
# -------------------------------
# loss: 0.032376  [    0/ 8760]
# Test Error:
#  MAPE: 3.74%, Avg loss: 0.078214
#
# Epoch 105
# -------------------------------
# loss: 0.031654  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.078273
#
# Epoch 106
# -------------------------------
# loss: 0.029510  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.082038
#
# Epoch 107
# -------------------------------
# loss: 0.033996  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.082379
#
# Epoch 108
# -------------------------------
# loss: 0.030917  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.084132
#
# Epoch 109
# -------------------------------
# loss: 0.032683  [    0/ 8760]
# Test Error:
#  MAPE: 3.75%, Avg loss: 0.075418
#
# Epoch 110
# -------------------------------
# loss: 0.029459  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.091160
#
# Epoch 111
# -------------------------------
# loss: 0.030446  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.084383
#
# Epoch 112
# -------------------------------
# loss: 0.035473  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.080362
#
# Epoch 113
# -------------------------------
# loss: 0.034492  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.083288
#
# Epoch 114
# -------------------------------
# loss: 0.030645  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.083255
#
# Epoch 115
# -------------------------------
# loss: 0.031933  [    0/ 8760]
# Test Error:
#  MAPE: 3.76%, Avg loss: 0.077841
#
# Epoch 116
# -------------------------------
# loss: 0.031419  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.084790
#
# Epoch 117
# -------------------------------
# loss: 0.031121  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.080844
#
# Epoch 118
# -------------------------------
# loss: 0.032326  [    0/ 8760]
# Test Error:
#  MAPE: 3.76%, Avg loss: 0.080247
#
# Epoch 119
# -------------------------------
# loss: 0.029259  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.079428
#
# Epoch 120
# -------------------------------
# loss: 0.026997  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.086111
#
# Epoch 121
# -------------------------------
# loss: 0.036207  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.082746
#
# Epoch 122
# -------------------------------
# loss: 0.032186  [    0/ 8760]
# Test Error:
#  MAPE: 3.77%, Avg loss: 0.076418
#
# Epoch 123
# -------------------------------
# loss: 0.029352  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.087291
#
# Epoch 124
# -------------------------------
# loss: 0.029430  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.083545
#
# Epoch 125
# -------------------------------
# loss: 0.031157  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.082900
#
# Epoch 126
# -------------------------------
# loss: 0.029490  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.085018
#
# Epoch 127
# -------------------------------
# loss: 0.029419  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.084850
#
# Epoch 128
# -------------------------------
# loss: 0.032897  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.079108
#
# Epoch 129
# -------------------------------
# loss: 0.029634  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.089262
#
# Epoch 130
# -------------------------------
# loss: 0.031465  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.083921
#
# Epoch 131
# -------------------------------
# loss: 0.029274  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.081884
#
# Epoch 132
# -------------------------------
# loss: 0.027454  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.083838
#
# Epoch 133
# -------------------------------
# loss: 0.033074  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.084443
#
# Epoch 134
# -------------------------------
# loss: 0.031162  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.084512
#
# Epoch 135
# -------------------------------
# loss: 0.032640  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.082499
#
# Epoch 136
# -------------------------------
# loss: 0.028625  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.087359
#
# Epoch 137
# -------------------------------
# loss: 0.030629  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.084266
#
# Epoch 138
# -------------------------------
# loss: 0.031327  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.081962
#
# Epoch 139
# -------------------------------
# loss: 0.029468  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.085910
#
# Epoch 140
# -------------------------------
# loss: 0.027402  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.085721
#
# Epoch 141
# -------------------------------
# loss: 0.028464  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.082121
#
# Epoch 142
# -------------------------------
# loss: 0.030652  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.088581
#
# Epoch 143
# -------------------------------
# loss: 0.026872  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.084488
#
# Epoch 144
# -------------------------------
# loss: 0.033301  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.082662
#
# Epoch 145
# -------------------------------
# loss: 0.027859  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.084592
#
# Epoch 146
# -------------------------------
# loss: 0.029148  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.087494
#
# Epoch 147
# -------------------------------
# loss: 0.028932  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.086045
#
# Epoch 148
# -------------------------------
# loss: 0.025736  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.080333
#
# Epoch 149
# -------------------------------
# loss: 0.027445  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.087867
#
# Epoch 150
# -------------------------------
# loss: 0.029445  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.088835
#
# Epoch 151
# -------------------------------
# loss: 0.031383  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.082626
#
# Epoch 152
# -------------------------------
# loss: 0.030429  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.082088
#
# Epoch 153
# -------------------------------
# loss: 0.026432  [    0/ 8760]
# Test Error:
#  MAPE: 4.02%, Avg loss: 0.088596
#
# Epoch 154
# -------------------------------
# loss: 0.032754  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.091260
#
# Epoch 155
# -------------------------------
# loss: 0.030614  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.086291
#
# Epoch 156
# -------------------------------
# loss: 0.027834  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.084229
#
# Epoch 157
# -------------------------------
# loss: 0.029395  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.083458
#
# Epoch 158
# -------------------------------
# loss: 0.028171  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.087741
#
# Epoch 159
# -------------------------------
# loss: 0.028390  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.085306
#
# Epoch 160
# -------------------------------
# loss: 0.032917  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.082875
#
# Epoch 161
# -------------------------------
# loss: 0.027720  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.085802
#
# Epoch 162
# -------------------------------
# loss: 0.026853  [    0/ 8760]
# Test Error:
#  MAPE: 3.93%, Avg loss: 0.086215
#
# Epoch 163
# -------------------------------
# loss: 0.026047  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.089284
#
# Epoch 164
# -------------------------------
# loss: 0.032824  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.082860
#
# Epoch 165
# -------------------------------
# loss: 0.033154  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.087261
#
# Epoch 166
# -------------------------------
# loss: 0.028070  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.087334
#
# Epoch 167
# -------------------------------
# loss: 0.028382  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.084051
#
# Epoch 168
# -------------------------------
# loss: 0.029191  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.084740
#
# Epoch 169
# -------------------------------
# loss: 0.026873  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.086847
#
# Epoch 170
# -------------------------------
# loss: 0.025403  [    0/ 8760]
# Test Error:
#  MAPE: 3.93%, Avg loss: 0.089014
#
# Epoch 171
# -------------------------------
# loss: 0.029273  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.082286
#
# Epoch 172
# -------------------------------
# loss: 0.028355  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.087004
#
# Epoch 173
# -------------------------------
# loss: 0.027190  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.087531
#
# Epoch 174
# -------------------------------
# loss: 0.028422  [    0/ 8760]
# Test Error:
#  MAPE: 3.90%, Avg loss: 0.088443
#
# Epoch 175
# -------------------------------
# loss: 0.028585  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.081814
#
# Epoch 176
# -------------------------------
# loss: 0.030914  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.088535
#
# Epoch 177
# -------------------------------
# loss: 0.027846  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.088060
#
# Epoch 178
# -------------------------------
# loss: 0.027085  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.091437
#
# Epoch 179
# -------------------------------
# loss: 0.030052  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.086543
#
# Epoch 180
# -------------------------------
# loss: 0.025941  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.084509
#
# Epoch 181
# -------------------------------
# loss: 0.027112  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.089090
#
# Epoch 182
# -------------------------------
# loss: 0.026053  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.086224
#
# Epoch 183
# -------------------------------
# loss: 0.032808  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.084327
#
# Epoch 184
# -------------------------------
# loss: 0.028132  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.084327
#
# Epoch 185
# -------------------------------
# loss: 0.026728  [    0/ 8760]
# Test Error:
#  MAPE: 3.93%, Avg loss: 0.088166
#
# Epoch 186
# -------------------------------
# loss: 0.024982  [    0/ 8760]
# Test Error:
#  MAPE: 3.90%, Avg loss: 0.090286
#
# Epoch 187
# -------------------------------
# loss: 0.031906  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.086554
#
# Epoch 188
# -------------------------------
# loss: 0.028166  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.081365
#
# Epoch 189
# -------------------------------
# loss: 0.026266  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.088561
#
# Epoch 190
# -------------------------------
# loss: 0.028411  [    0/ 8760]
# Test Error:
#  MAPE: 3.93%, Avg loss: 0.089991
#
# Epoch 191
# -------------------------------
# loss: 0.026342  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.085789
#
# Epoch 192
# -------------------------------
# loss: 0.025753  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.083616
#
# Epoch 193
# -------------------------------
# loss: 0.025287  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.086427
#
# Epoch 194
# -------------------------------
# loss: 0.027291  [    0/ 8760]
# Test Error:
#  MAPE: 4.00%, Avg loss: 0.094835
#
# Epoch 195
# -------------------------------
# loss: 0.026246  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.087530
#
# Epoch 196
# -------------------------------
# loss: 0.028301  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.092498
#
# Epoch 197
# -------------------------------
# loss: 0.029825  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.084385
#
# Epoch 198
# -------------------------------
# loss: 0.026641  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.084025
#
# Epoch 199
# -------------------------------
# loss: 0.028609  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.091809
#
# Epoch 200
# -------------------------------
# loss: 0.023742  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.088861
#
# Done!

# %% [markdown]
# The following two problems are independent. Each is based on your revised code above (with $1024$ and $512$ units).
#
# ## Problem 2
#
# One method to mitigate the overfitting in Problem 1 is to use ridge regularization (L2 regularization). Based on your solution to Problem 1, set `weight_decay=0.01` in the proper function, and run your code.

# %%
# Your code
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(44, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 1)
        )

    def forward(self, x):
        return self.fc(x)

model = NeuralNetwork()
loss_fn = nn.MSELoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=1e-3, weight_decay=0.01)

epochs = 200
for t in range(epochs):
    print('Epoch', t + 1)
    print('-------------------------------')
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.701757  [    0/ 8760]
# Test Error:
#  MAPE: 8.91%, Avg loss: 0.328127
#
# Epoch 2
# -------------------------------
# loss: 0.187449  [    0/ 8760]
# Test Error:
#  MAPE: 8.45%, Avg loss: 0.316508
#
# Epoch 3
# -------------------------------
# loss: 0.172342  [    0/ 8760]
# Test Error:
#  MAPE: 8.27%, Avg loss: 0.303339
#
# Epoch 4
# -------------------------------
# loss: 0.133997  [    0/ 8760]
# Test Error:
#  MAPE: 7.99%, Avg loss: 0.290551
#
# Epoch 5
# -------------------------------
# loss: 0.131401  [    0/ 8760]
# Test Error:
#  MAPE: 7.58%, Avg loss: 0.262186
#
# Epoch 6
# -------------------------------
# loss: 0.103009  [    0/ 8760]
# Test Error:
#  MAPE: 7.26%, Avg loss: 0.239464
#
# Epoch 7
# -------------------------------
# loss: 0.091093  [    0/ 8760]
# Test Error:
#  MAPE: 6.97%, Avg loss: 0.221263
#
# Epoch 8
# -------------------------------
# loss: 0.091037  [    0/ 8760]
# Test Error:
#  MAPE: 6.78%, Avg loss: 0.209646
#
# Epoch 9
# -------------------------------
# loss: 0.100194  [    0/ 8760]
# Test Error:
#  MAPE: 6.55%, Avg loss: 0.197453
#
# Epoch 10
# -------------------------------
# loss: 0.089906  [    0/ 8760]
# Test Error:
#  MAPE: 6.46%, Avg loss: 0.191150
#
# Epoch 11
# -------------------------------
# loss: 0.101669  [    0/ 8760]
# Test Error:
#  MAPE: 6.27%, Avg loss: 0.182333
#
# Epoch 12
# -------------------------------
# loss: 0.075982  [    0/ 8760]
# Test Error:
#  MAPE: 6.19%, Avg loss: 0.177276
#
# Epoch 13
# -------------------------------
# loss: 0.091322  [    0/ 8760]
# Test Error:
#  MAPE: 6.03%, Avg loss: 0.169685
#
# Epoch 14
# -------------------------------
# loss: 0.071931  [    0/ 8760]
# Test Error:
#  MAPE: 5.91%, Avg loss: 0.164088
#
# Epoch 15
# -------------------------------
# loss: 0.065253  [    0/ 8760]
# Test Error:
#  MAPE: 5.84%, Avg loss: 0.160257
#
# Epoch 16
# -------------------------------
# loss: 0.076389  [    0/ 8760]
# Test Error:
#  MAPE: 5.74%, Avg loss: 0.155573
#
# Epoch 17
# -------------------------------
# loss: 0.065909  [    0/ 8760]
# Test Error:
#  MAPE: 5.61%, Avg loss: 0.149619
#
# Epoch 18
# -------------------------------
# loss: 0.061103  [    0/ 8760]
# Test Error:
#  MAPE: 5.52%, Avg loss: 0.146078
#
# Epoch 19
# -------------------------------
# loss: 0.060710  [    0/ 8760]
# Test Error:
#  MAPE: 5.44%, Avg loss: 0.142772
#
# Epoch 20
# -------------------------------
# loss: 0.060351  [    0/ 8760]
# Test Error:
#  MAPE: 5.35%, Avg loss: 0.138853
#
# Epoch 21
# -------------------------------
# loss: 0.059427  [    0/ 8760]
# Test Error:
#  MAPE: 5.28%, Avg loss: 0.135844
#
# Epoch 22
# -------------------------------
# loss: 0.059369  [    0/ 8760]
# Test Error:
#  MAPE: 5.22%, Avg loss: 0.133419
#
# Epoch 23
# -------------------------------
# loss: 0.059045  [    0/ 8760]
# Test Error:
#  MAPE: 5.15%, Avg loss: 0.131067
#
# Epoch 24
# -------------------------------
# loss: 0.057770  [    0/ 8760]
# Test Error:
#  MAPE: 5.09%, Avg loss: 0.128562
#
# Epoch 25
# -------------------------------
# loss: 0.057928  [    0/ 8760]
# Test Error:
#  MAPE: 5.04%, Avg loss: 0.126394
#
# Epoch 26
# -------------------------------
# loss: 0.057982  [    0/ 8760]
# Test Error:
#  MAPE: 4.98%, Avg loss: 0.124087
#
# Epoch 27
# -------------------------------
# loss: 0.056477  [    0/ 8760]
# Test Error:
#  MAPE: 4.93%, Avg loss: 0.122368
#
# Epoch 28
# -------------------------------
# loss: 0.055552  [    0/ 8760]
# Test Error:
#  MAPE: 4.90%, Avg loss: 0.120655
#
# Epoch 29
# -------------------------------
# loss: 0.055274  [    0/ 8760]
# Test Error:
#  MAPE: 4.83%, Avg loss: 0.118044
#
# Epoch 30
# -------------------------------
# loss: 0.055149  [    0/ 8760]
# Test Error:
#  MAPE: 4.79%, Avg loss: 0.116195
#
# Epoch 31
# -------------------------------
# loss: 0.054810  [    0/ 8760]
# Test Error:
#  MAPE: 4.77%, Avg loss: 0.115613
#
# Epoch 32
# -------------------------------
# loss: 0.053759  [    0/ 8760]
# Test Error:
#  MAPE: 4.73%, Avg loss: 0.113945
#
# Epoch 33
# -------------------------------
# loss: 0.054242  [    0/ 8760]
# Test Error:
#  MAPE: 4.68%, Avg loss: 0.111901
#
# Epoch 34
# -------------------------------
# loss: 0.053275  [    0/ 8760]
# Test Error:
#  MAPE: 4.66%, Avg loss: 0.110982
#
# Epoch 35
# -------------------------------
# loss: 0.053599  [    0/ 8760]
# Test Error:
#  MAPE: 4.62%, Avg loss: 0.109867
#
# Epoch 36
# -------------------------------
# loss: 0.052717  [    0/ 8760]
# Test Error:
#  MAPE: 4.58%, Avg loss: 0.107889
#
# Epoch 37
# -------------------------------
# loss: 0.052973  [    0/ 8760]
# Test Error:
#  MAPE: 4.56%, Avg loss: 0.107437
#
# Epoch 38
# -------------------------------
# loss: 0.052384  [    0/ 8760]
# Test Error:
#  MAPE: 4.54%, Avg loss: 0.106131
#
# Epoch 39
# -------------------------------
# loss: 0.052382  [    0/ 8760]
# Test Error:
#  MAPE: 4.51%, Avg loss: 0.105433
#
# Epoch 40
# -------------------------------
# loss: 0.052001  [    0/ 8760]
# Test Error:
#  MAPE: 4.49%, Avg loss: 0.104617
#
# Epoch 41
# -------------------------------
# loss: 0.052409  [    0/ 8760]
# Test Error:
#  MAPE: 4.48%, Avg loss: 0.104004
#
# Epoch 42
# -------------------------------
# loss: 0.052452  [    0/ 8760]
# Test Error:
#  MAPE: 4.46%, Avg loss: 0.103172
#
# Epoch 43
# -------------------------------
# loss: 0.052795  [    0/ 8760]
# Test Error:
#  MAPE: 4.43%, Avg loss: 0.101770
#
# Epoch 44
# -------------------------------
# loss: 0.052095  [    0/ 8760]
# Test Error:
#  MAPE: 4.41%, Avg loss: 0.101022
#
# Epoch 45
# -------------------------------
# loss: 0.051325  [    0/ 8760]
# Test Error:
#  MAPE: 4.41%, Avg loss: 0.100801
#
# Epoch 46
# -------------------------------
# loss: 0.052195  [    0/ 8760]
# Test Error:
#  MAPE: 4.37%, Avg loss: 0.099380
#
# Epoch 47
# -------------------------------
# loss: 0.051640  [    0/ 8760]
# Test Error:
#  MAPE: 4.36%, Avg loss: 0.098884
#
# Epoch 48
# -------------------------------
# loss: 0.051471  [    0/ 8760]
# Test Error:
#  MAPE: 4.36%, Avg loss: 0.098570
#
# Epoch 49
# -------------------------------
# loss: 0.051253  [    0/ 8760]
# Test Error:
#  MAPE: 4.31%, Avg loss: 0.097212
#
# Epoch 50
# -------------------------------
# loss: 0.050970  [    0/ 8760]
# Test Error:
#  MAPE: 4.32%, Avg loss: 0.097261
#
# Epoch 51
# -------------------------------
# loss: 0.051604  [    0/ 8760]
# Test Error:
#  MAPE: 4.29%, Avg loss: 0.096325
#
# Epoch 52
# -------------------------------
# loss: 0.051150  [    0/ 8760]
# Test Error:
#  MAPE: 4.28%, Avg loss: 0.095635
#
# Epoch 53
# -------------------------------
# loss: 0.051070  [    0/ 8760]
# Test Error:
#  MAPE: 4.29%, Avg loss: 0.096382
#
# Epoch 54
# -------------------------------
# loss: 0.051060  [    0/ 8760]
# Test Error:
#  MAPE: 4.27%, Avg loss: 0.095546
#
# Epoch 55
# -------------------------------
# loss: 0.051311  [    0/ 8760]
# Test Error:
#  MAPE: 4.24%, Avg loss: 0.094213
#
# Epoch 56
# -------------------------------
# loss: 0.049917  [    0/ 8760]
# Test Error:
#  MAPE: 4.23%, Avg loss: 0.093718
#
# Epoch 57
# -------------------------------
# loss: 0.050128  [    0/ 8760]
# Test Error:
#  MAPE: 4.21%, Avg loss: 0.093006
#
# Epoch 58
# -------------------------------
# loss: 0.049813  [    0/ 8760]
# Test Error:
#  MAPE: 4.23%, Avg loss: 0.093485
#
# Epoch 59
# -------------------------------
# loss: 0.050374  [    0/ 8760]
# Test Error:
#  MAPE: 4.22%, Avg loss: 0.093271
#
# Epoch 60
# -------------------------------
# loss: 0.050603  [    0/ 8760]
# Test Error:
#  MAPE: 4.20%, Avg loss: 0.092344
#
# Epoch 61
# -------------------------------
# loss: 0.050367  [    0/ 8760]
# Test Error:
#  MAPE: 4.20%, Avg loss: 0.092185
#
# Epoch 62
# -------------------------------
# loss: 0.050609  [    0/ 8760]
# Test Error:
#  MAPE: 4.20%, Avg loss: 0.091890
#
# Epoch 63
# -------------------------------
# loss: 0.049932  [    0/ 8760]
# Test Error:
#  MAPE: 4.18%, Avg loss: 0.091565
#
# Epoch 64
# -------------------------------
# loss: 0.050084  [    0/ 8760]
# Test Error:
#  MAPE: 4.18%, Avg loss: 0.091540
#
# Epoch 65
# -------------------------------
# loss: 0.050708  [    0/ 8760]
# Test Error:
#  MAPE: 4.18%, Avg loss: 0.091360
#
# Epoch 66
# -------------------------------
# loss: 0.050101  [    0/ 8760]
# Test Error:
#  MAPE: 4.14%, Avg loss: 0.089902
#
# Epoch 67
# -------------------------------
# loss: 0.050181  [    0/ 8760]
# Test Error:
#  MAPE: 4.16%, Avg loss: 0.090474
#
# Epoch 68
# -------------------------------
# loss: 0.051389  [    0/ 8760]
# Test Error:
#  MAPE: 4.13%, Avg loss: 0.089347
#
# Epoch 69
# -------------------------------
# loss: 0.050461  [    0/ 8760]
# Test Error:
#  MAPE: 4.13%, Avg loss: 0.089212
#
# Epoch 70
# -------------------------------
# loss: 0.050009  [    0/ 8760]
# Test Error:
#  MAPE: 4.13%, Avg loss: 0.088934
#
# Epoch 71
# -------------------------------
# loss: 0.049964  [    0/ 8760]
# Test Error:
#  MAPE: 4.12%, Avg loss: 0.088670
#
# Epoch 72
# -------------------------------
# loss: 0.051150  [    0/ 8760]
# Test Error:
#  MAPE: 4.12%, Avg loss: 0.088610
#
# Epoch 73
# -------------------------------
# loss: 0.050432  [    0/ 8760]
# Test Error:
#  MAPE: 4.11%, Avg loss: 0.088102
#
# Epoch 74
# -------------------------------
# loss: 0.051075  [    0/ 8760]
# Test Error:
#  MAPE: 4.10%, Avg loss: 0.087896
#
# Epoch 75
# -------------------------------
# loss: 0.051462  [    0/ 8760]
# Test Error:
#  MAPE: 4.10%, Avg loss: 0.087687
#
# Epoch 76
# -------------------------------
# loss: 0.050463  [    0/ 8760]
# Test Error:
#  MAPE: 4.09%, Avg loss: 0.087453
#
# Epoch 77
# -------------------------------
# loss: 0.051011  [    0/ 8760]
# Test Error:
#  MAPE: 4.09%, Avg loss: 0.087065
#
# Epoch 78
# -------------------------------
# loss: 0.050192  [    0/ 8760]
# Test Error:
#  MAPE: 4.09%, Avg loss: 0.087076
#
# Epoch 79
# -------------------------------
# loss: 0.051009  [    0/ 8760]
# Test Error:
#  MAPE: 4.08%, Avg loss: 0.086436
#
# Epoch 80
# -------------------------------
# loss: 0.051927  [    0/ 8760]
# Test Error:
#  MAPE: 4.04%, Avg loss: 0.085585
#
# Epoch 81
# -------------------------------
# loss: 0.052561  [    0/ 8760]
# Test Error:
#  MAPE: 4.04%, Avg loss: 0.085445
#
# Epoch 82
# -------------------------------
# loss: 0.052091  [    0/ 8760]
# Test Error:
#  MAPE: 4.04%, Avg loss: 0.085357
#
# Epoch 83
# -------------------------------
# loss: 0.050203  [    0/ 8760]
# Test Error:
#  MAPE: 4.04%, Avg loss: 0.085157
#
# Epoch 84
# -------------------------------
# loss: 0.051435  [    0/ 8760]
# Test Error:
#  MAPE: 4.03%, Avg loss: 0.084665
#
# Epoch 85
# -------------------------------
# loss: 0.051896  [    0/ 8760]
# Test Error:
#  MAPE: 4.05%, Avg loss: 0.085033
#
# Epoch 86
# -------------------------------
# loss: 0.051601  [    0/ 8760]
# Test Error:
#  MAPE: 4.03%, Avg loss: 0.084743
#
# Epoch 87
# -------------------------------
# loss: 0.052331  [    0/ 8760]
# Test Error:
#  MAPE: 4.05%, Avg loss: 0.084959
#
# Epoch 88
# -------------------------------
# loss: 0.050722  [    0/ 8760]
# Test Error:
#  MAPE: 4.03%, Avg loss: 0.084485
#
# Epoch 89
# -------------------------------
# loss: 0.050423  [    0/ 8760]
# Test Error:
#  MAPE: 4.03%, Avg loss: 0.084008
#
# Epoch 90
# -------------------------------
# loss: 0.051269  [    0/ 8760]
# Test Error:
#  MAPE: 4.01%, Avg loss: 0.083679
#
# Epoch 91
# -------------------------------
# loss: 0.051428  [    0/ 8760]
# Test Error:
#  MAPE: 4.03%, Avg loss: 0.084273
#
# Epoch 92
# -------------------------------
# loss: 0.052979  [    0/ 8760]
# Test Error:
#  MAPE: 4.02%, Avg loss: 0.083774
#
# Epoch 93
# -------------------------------
# loss: 0.053286  [    0/ 8760]
# Test Error:
#  MAPE: 4.00%, Avg loss: 0.083003
#
# Epoch 94
# -------------------------------
# loss: 0.051605  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.082581
#
# Epoch 95
# -------------------------------
# loss: 0.051078  [    0/ 8760]
# Test Error:
#  MAPE: 4.00%, Avg loss: 0.083085
#
# Epoch 96
# -------------------------------
# loss: 0.052081  [    0/ 8760]
# Test Error:
#  MAPE: 4.01%, Avg loss: 0.083251
#
# Epoch 97
# -------------------------------
# loss: 0.051728  [    0/ 8760]
# Test Error:
#  MAPE: 4.01%, Avg loss: 0.082877
#
# Epoch 98
# -------------------------------
# loss: 0.050794  [    0/ 8760]
# Test Error:
#  MAPE: 3.99%, Avg loss: 0.082408
#
# Epoch 99
# -------------------------------
# loss: 0.050668  [    0/ 8760]
# Test Error:
#  MAPE: 4.00%, Avg loss: 0.082853
#
# Epoch 100
# -------------------------------
# loss: 0.051704  [    0/ 8760]
# Test Error:
#  MAPE: 4.01%, Avg loss: 0.082731
#
# Epoch 101
# -------------------------------
# loss: 0.051564  [    0/ 8760]
# Test Error:
#  MAPE: 4.00%, Avg loss: 0.082530
#
# Epoch 102
# -------------------------------
# loss: 0.052049  [    0/ 8760]
# Test Error:
#  MAPE: 3.99%, Avg loss: 0.082264
#
# Epoch 103
# -------------------------------
# loss: 0.051367  [    0/ 8760]
# Test Error:
#  MAPE: 4.00%, Avg loss: 0.082533
#
# Epoch 104
# -------------------------------
# loss: 0.051516  [    0/ 8760]
# Test Error:
#  MAPE: 4.00%, Avg loss: 0.082099
#
# Epoch 105
# -------------------------------
# loss: 0.051475  [    0/ 8760]
# Test Error:
#  MAPE: 3.99%, Avg loss: 0.081762
#
# Epoch 106
# -------------------------------
# loss: 0.051171  [    0/ 8760]
# Test Error:
#  MAPE: 4.00%, Avg loss: 0.082072
#
# Epoch 107
# -------------------------------
# loss: 0.051710  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.081643
#
# Epoch 108
# -------------------------------
# loss: 0.050758  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.081309
#
# Epoch 109
# -------------------------------
# loss: 0.052181  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.081615
#
# Epoch 110
# -------------------------------
# loss: 0.051140  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.081836
#
# Epoch 111
# -------------------------------
# loss: 0.051059  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.081217
#
# Epoch 112
# -------------------------------
# loss: 0.051750  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.081016
#
# Epoch 113
# -------------------------------
# loss: 0.052496  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.080806
#
# Epoch 114
# -------------------------------
# loss: 0.051576  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.081108
#
# Epoch 115
# -------------------------------
# loss: 0.051373  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.080949
#
# Epoch 116
# -------------------------------
# loss: 0.051257  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.080799
#
# Epoch 117
# -------------------------------
# loss: 0.051319  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.081120
#
# Epoch 118
# -------------------------------
# loss: 0.052727  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.081013
#
# Epoch 119
# -------------------------------
# loss: 0.052683  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.081101
#
# Epoch 120
# -------------------------------
# loss: 0.051958  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.081019
#
# Epoch 121
# -------------------------------
# loss: 0.050527  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.080373
#
# Epoch 122
# -------------------------------
# loss: 0.050477  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.080711
#
# Epoch 123
# -------------------------------
# loss: 0.052159  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.080843
#
# Epoch 124
# -------------------------------
# loss: 0.053525  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.080489
#
# Epoch 125
# -------------------------------
# loss: 0.052356  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.080332
#
# Epoch 126
# -------------------------------
# loss: 0.051943  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.080925
#
# Epoch 127
# -------------------------------
# loss: 0.051799  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.080470
#
# Epoch 128
# -------------------------------
# loss: 0.051078  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.080417
#
# Epoch 129
# -------------------------------
# loss: 0.051032  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.080886
#
# Epoch 130
# -------------------------------
# loss: 0.051921  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.080253
#
# Epoch 131
# -------------------------------
# loss: 0.051702  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.079538
#
# Epoch 132
# -------------------------------
# loss: 0.050976  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.079705
#
# Epoch 133
# -------------------------------
# loss: 0.052128  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.080438
#
# Epoch 134
# -------------------------------
# loss: 0.051824  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.079837
#
# Epoch 135
# -------------------------------
# loss: 0.052131  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.080015
#
# Epoch 136
# -------------------------------
# loss: 0.052340  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.079278
#
# Epoch 137
# -------------------------------
# loss: 0.051490  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.078956
#
# Epoch 138
# -------------------------------
# loss: 0.051901  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.078845
#
# Epoch 139
# -------------------------------
# loss: 0.050013  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.078706
#
# Epoch 140
# -------------------------------
# loss: 0.050013  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.078079
#
# Epoch 141
# -------------------------------
# loss: 0.050896  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.078036
#
# Epoch 142
# -------------------------------
# loss: 0.049763  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.078492
#
# Epoch 143
# -------------------------------
# loss: 0.050101  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.078114
#
# Epoch 144
# -------------------------------
# loss: 0.049565  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.078397
#
# Epoch 145
# -------------------------------
# loss: 0.048865  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.078210
#
# Epoch 146
# -------------------------------
# loss: 0.050616  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.078249
#
# Epoch 147
# -------------------------------
# loss: 0.049626  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.077276
#
# Epoch 148
# -------------------------------
# loss: 0.050865  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.077493
#
# Epoch 149
# -------------------------------
# loss: 0.050935  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.077846
#
# Epoch 150
# -------------------------------
# loss: 0.050347  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.077703
#
# Epoch 151
# -------------------------------
# loss: 0.050192  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.078025
#
# Epoch 152
# -------------------------------
# loss: 0.051231  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.077784
#
# Epoch 153
# -------------------------------
# loss: 0.050303  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.077446
#
# Epoch 154
# -------------------------------
# loss: 0.051109  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.077347
#
# Epoch 155
# -------------------------------
# loss: 0.051172  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.076915
#
# Epoch 156
# -------------------------------
# loss: 0.049350  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.077074
#
# Epoch 157
# -------------------------------
# loss: 0.050625  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.077271
#
# Epoch 158
# -------------------------------
# loss: 0.052326  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.077572
#
# Epoch 159
# -------------------------------
# loss: 0.051338  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.077903
#
# Epoch 160
# -------------------------------
# loss: 0.052164  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.077691
#
# Epoch 161
# -------------------------------
# loss: 0.051351  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.077529
#
# Epoch 162
# -------------------------------
# loss: 0.050853  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.077231
#
# Epoch 163
# -------------------------------
# loss: 0.051724  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.076870
#
# Epoch 164
# -------------------------------
# loss: 0.050275  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.077669
#
# Epoch 165
# -------------------------------
# loss: 0.052119  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.076883
#
# Epoch 166
# -------------------------------
# loss: 0.050032  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.076684
#
# Epoch 167
# -------------------------------
# loss: 0.050778  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.076420
#
# Epoch 168
# -------------------------------
# loss: 0.050254  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.077124
#
# Epoch 169
# -------------------------------
# loss: 0.050926  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.076958
#
# Epoch 170
# -------------------------------
# loss: 0.050190  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.076389
#
# Epoch 171
# -------------------------------
# loss: 0.050363  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.076242
#
# Epoch 172
# -------------------------------
# loss: 0.050796  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.076463
#
# Epoch 173
# -------------------------------
# loss: 0.049574  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.076713
#
# Epoch 174
# -------------------------------
# loss: 0.050384  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.076527
#
# Epoch 175
# -------------------------------
# loss: 0.050375  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.076672
#
# Epoch 176
# -------------------------------
# loss: 0.050252  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.076641
#
# Epoch 177
# -------------------------------
# loss: 0.050946  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.076117
#
# Epoch 178
# -------------------------------
# loss: 0.049919  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.076043
#
# Epoch 179
# -------------------------------
# loss: 0.051059  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.076563
#
# Epoch 180
# -------------------------------
# loss: 0.050491  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.076324
#
# Epoch 181
# -------------------------------
# loss: 0.050347  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.076683
#
# Epoch 182
# -------------------------------
# loss: 0.050421  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.075998
#
# Epoch 183
# -------------------------------
# loss: 0.050303  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.075934
#
# Epoch 184
# -------------------------------
# loss: 0.049211  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.075932
#
# Epoch 185
# -------------------------------
# loss: 0.049821  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.075718
#
# Epoch 186
# -------------------------------
# loss: 0.050751  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.075944
#
# Epoch 187
# -------------------------------
# loss: 0.051153  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.075843
#
# Epoch 188
# -------------------------------
# loss: 0.050393  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.075689
#
# Epoch 189
# -------------------------------
# loss: 0.050319  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.075767
#
# Epoch 190
# -------------------------------
# loss: 0.049862  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.075728
#
# Epoch 191
# -------------------------------
# loss: 0.050821  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.075989
#
# Epoch 192
# -------------------------------
# loss: 0.050725  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.075382
#
# Epoch 193
# -------------------------------
# loss: 0.049760  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.075105
#
# Epoch 194
# -------------------------------
# loss: 0.049794  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.075570
#
# Epoch 195
# -------------------------------
# loss: 0.050438  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.075676
#
# Epoch 196
# -------------------------------
# loss: 0.051567  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.075291
#
# Epoch 197
# -------------------------------
# loss: 0.048795  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.075175
#
# Epoch 198
# -------------------------------
# loss: 0.050190  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.074977
#
# Epoch 199
# -------------------------------
# loss: 0.049863  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.075280
#
# Epoch 200
# -------------------------------
# loss: 0.050496  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.075012
#
# Done!

# %% [markdown]
# ## Problem 3
#
# Another method to mitigate the overfitting in Problem 1 is to use dropout. Based on your solution to Problem 1, add a dropout layer with dropout rate $0.5$ after each of the two hidden layers (more specifically, after each activation function), and run your code.

# %%
# Your code
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(44, 1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, 1)
        )

    def forward(self, x):
        return self.fc(x)

model = NeuralNetwork()
loss_fn = nn.MSELoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=1e-3)

epochs = 200
for t in range(epochs):
    print('Epoch', t + 1)
    print('-------------------------------')
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.716121  [    0/ 8760]
# Test Error:
#  MAPE: 9.20%, Avg loss: 0.355622
#
# Epoch 2
# -------------------------------
# loss: 0.599660  [    0/ 8760]
# Test Error:
#  MAPE: 8.31%, Avg loss: 0.316055
#
# Epoch 3
# -------------------------------
# loss: 0.408592  [    0/ 8760]
# Test Error:
#  MAPE: 7.77%, Avg loss: 0.276318
#
# Epoch 4
# -------------------------------
# loss: 0.270881  [    0/ 8760]
# Test Error:
#  MAPE: 7.31%, Avg loss: 0.248580
#
# Epoch 5
# -------------------------------
# loss: 0.191594  [    0/ 8760]
# Test Error:
#  MAPE: 6.99%, Avg loss: 0.225856
#
# Epoch 6
# -------------------------------
# loss: 0.145112  [    0/ 8760]
# Test Error:
#  MAPE: 6.74%, Avg loss: 0.208312
#
# Epoch 7
# -------------------------------
# loss: 0.128689  [    0/ 8760]
# Test Error:
#  MAPE: 6.52%, Avg loss: 0.196386
#
# Epoch 8
# -------------------------------
# loss: 0.116127  [    0/ 8760]
# Test Error:
#  MAPE: 6.47%, Avg loss: 0.188354
#
# Epoch 9
# -------------------------------
# loss: 0.127898  [    0/ 8760]
# Test Error:
#  MAPE: 6.49%, Avg loss: 0.184964
#
# Epoch 10
# -------------------------------
# loss: 0.099664  [    0/ 8760]
# Test Error:
#  MAPE: 6.10%, Avg loss: 0.167514
#
# Epoch 11
# -------------------------------
# loss: 0.099280  [    0/ 8760]
# Test Error:
#  MAPE: 6.11%, Avg loss: 0.161763
#
# Epoch 12
# -------------------------------
# loss: 0.086580  [    0/ 8760]
# Test Error:
#  MAPE: 5.87%, Avg loss: 0.154087
#
# Epoch 13
# -------------------------------
# loss: 0.097152  [    0/ 8760]
# Test Error:
#  MAPE: 5.98%, Avg loss: 0.154439
#
# Epoch 14
# -------------------------------
# loss: 0.097989  [    0/ 8760]
# Test Error:
#  MAPE: 5.49%, Avg loss: 0.137633
#
# Epoch 15
# -------------------------------
# loss: 0.088680  [    0/ 8760]
# Test Error:
#  MAPE: 5.69%, Avg loss: 0.140508
#
# Epoch 16
# -------------------------------
# loss: 0.091914  [    0/ 8760]
# Test Error:
#  MAPE: 5.82%, Avg loss: 0.142063
#
# Epoch 17
# -------------------------------
# loss: 0.092140  [    0/ 8760]
# Test Error:
#  MAPE: 5.51%, Avg loss: 0.132075
#
# Epoch 18
# -------------------------------
# loss: 0.094335  [    0/ 8760]
# Test Error:
#  MAPE: 5.21%, Avg loss: 0.123171
#
# Epoch 19
# -------------------------------
# loss: 0.092132  [    0/ 8760]
# Test Error:
#  MAPE: 5.32%, Avg loss: 0.124772
#
# Epoch 20
# -------------------------------
# loss: 0.083036  [    0/ 8760]
# Test Error:
#  MAPE: 5.42%, Avg loss: 0.126018
#
# Epoch 21
# -------------------------------
# loss: 0.084716  [    0/ 8760]
# Test Error:
#  MAPE: 5.12%, Avg loss: 0.118521
#
# Epoch 22
# -------------------------------
# loss: 0.088832  [    0/ 8760]
# Test Error:
#  MAPE: 5.03%, Avg loss: 0.114997
#
# Epoch 23
# -------------------------------
# loss: 0.083650  [    0/ 8760]
# Test Error:
#  MAPE: 5.19%, Avg loss: 0.116246
#
# Epoch 24
# -------------------------------
# loss: 0.094791  [    0/ 8760]
# Test Error:
#  MAPE: 4.79%, Avg loss: 0.103628
#
# Epoch 25
# -------------------------------
# loss: 0.065517  [    0/ 8760]
# Test Error:
#  MAPE: 4.82%, Avg loss: 0.105721
#
# Epoch 26
# -------------------------------
# loss: 0.088070  [    0/ 8760]
# Test Error:
#  MAPE: 4.84%, Avg loss: 0.105426
#
# Epoch 27
# -------------------------------
# loss: 0.090270  [    0/ 8760]
# Test Error:
#  MAPE: 4.71%, Avg loss: 0.099684
#
# Epoch 28
# -------------------------------
# loss: 0.072634  [    0/ 8760]
# Test Error:
#  MAPE: 4.62%, Avg loss: 0.097965
#
# Epoch 29
# -------------------------------
# loss: 0.081987  [    0/ 8760]
# Test Error:
#  MAPE: 4.74%, Avg loss: 0.101376
#
# Epoch 30
# -------------------------------
# loss: 0.077546  [    0/ 8760]
# Test Error:
#  MAPE: 4.64%, Avg loss: 0.098085
#
# Epoch 31
# -------------------------------
# loss: 0.078384  [    0/ 8760]
# Test Error:
#  MAPE: 4.74%, Avg loss: 0.100587
#
# Epoch 32
# -------------------------------
# loss: 0.067916  [    0/ 8760]
# Test Error:
#  MAPE: 4.83%, Avg loss: 0.100657
#
# Epoch 33
# -------------------------------
# loss: 0.067346  [    0/ 8760]
# Test Error:
#  MAPE: 4.75%, Avg loss: 0.099042
#
# Epoch 34
# -------------------------------
# loss: 0.068685  [    0/ 8760]
# Test Error:
#  MAPE: 4.92%, Avg loss: 0.103055
#
# Epoch 35
# -------------------------------
# loss: 0.062586  [    0/ 8760]
# Test Error:
#  MAPE: 4.66%, Avg loss: 0.098062
#
# Epoch 36
# -------------------------------
# loss: 0.077764  [    0/ 8760]
# Test Error:
#  MAPE: 4.36%, Avg loss: 0.088356
#
# Epoch 37
# -------------------------------
# loss: 0.073795  [    0/ 8760]
# Test Error:
#  MAPE: 4.28%, Avg loss: 0.086260
#
# Epoch 38
# -------------------------------
# loss: 0.059990  [    0/ 8760]
# Test Error:
#  MAPE: 4.40%, Avg loss: 0.087684
#
# Epoch 39
# -------------------------------
# loss: 0.070060  [    0/ 8760]
# Test Error:
#  MAPE: 4.43%, Avg loss: 0.091985
#
# Epoch 40
# -------------------------------
# loss: 0.092757  [    0/ 8760]
# Test Error:
#  MAPE: 4.28%, Avg loss: 0.085171
#
# Epoch 41
# -------------------------------
# loss: 0.070156  [    0/ 8760]
# Test Error:
#  MAPE: 4.29%, Avg loss: 0.085163
#
# Epoch 42
# -------------------------------
# loss: 0.067350  [    0/ 8760]
# Test Error:
#  MAPE: 4.13%, Avg loss: 0.081723
#
# Epoch 43
# -------------------------------
# loss: 0.071131  [    0/ 8760]
# Test Error:
#  MAPE: 4.32%, Avg loss: 0.085146
#
# Epoch 44
# -------------------------------
# loss: 0.079908  [    0/ 8760]
# Test Error:
#  MAPE: 4.54%, Avg loss: 0.089766
#
# Epoch 45
# -------------------------------
# loss: 0.063835  [    0/ 8760]
# Test Error:
#  MAPE: 4.52%, Avg loss: 0.089953
#
# Epoch 46
# -------------------------------
# loss: 0.075931  [    0/ 8760]
# Test Error:
#  MAPE: 4.25%, Avg loss: 0.083425
#
# Epoch 47
# -------------------------------
# loss: 0.068636  [    0/ 8760]
# Test Error:
#  MAPE: 4.12%, Avg loss: 0.080771
#
# Epoch 48
# -------------------------------
# loss: 0.081246  [    0/ 8760]
# Test Error:
#  MAPE: 4.31%, Avg loss: 0.084478
#
# Epoch 49
# -------------------------------
# loss: 0.066570  [    0/ 8760]
# Test Error:
#  MAPE: 4.28%, Avg loss: 0.084267
#
# Epoch 50
# -------------------------------
# loss: 0.064588  [    0/ 8760]
# Test Error:
#  MAPE: 4.19%, Avg loss: 0.080425
#
# Epoch 51
# -------------------------------
# loss: 0.057903  [    0/ 8760]
# Test Error:
#  MAPE: 4.17%, Avg loss: 0.080771
#
# Epoch 52
# -------------------------------
# loss: 0.070238  [    0/ 8760]
# Test Error:
#  MAPE: 4.21%, Avg loss: 0.083330
#
# Epoch 53
# -------------------------------
# loss: 0.062352  [    0/ 8760]
# Test Error:
#  MAPE: 4.05%, Avg loss: 0.077813
#
# Epoch 54
# -------------------------------
# loss: 0.064474  [    0/ 8760]
# Test Error:
#  MAPE: 4.16%, Avg loss: 0.081797
#
# Epoch 55
# -------------------------------
# loss: 0.072004  [    0/ 8760]
# Test Error:
#  MAPE: 3.99%, Avg loss: 0.077545
#
# Epoch 56
# -------------------------------
# loss: 0.074513  [    0/ 8760]
# Test Error:
#  MAPE: 4.18%, Avg loss: 0.083962
#
# Epoch 57
# -------------------------------
# loss: 0.064808  [    0/ 8760]
# Test Error:
#  MAPE: 3.99%, Avg loss: 0.077482
#
# Epoch 58
# -------------------------------
# loss: 0.064044  [    0/ 8760]
# Test Error:
#  MAPE: 4.32%, Avg loss: 0.083628
#
# Epoch 59
# -------------------------------
# loss: 0.058429  [    0/ 8760]
# Test Error:
#  MAPE: 4.07%, Avg loss: 0.078133
#
# Epoch 60
# -------------------------------
# loss: 0.056949  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.075725
#
# Epoch 61
# -------------------------------
# loss: 0.075988  [    0/ 8760]
# Test Error:
#  MAPE: 4.09%, Avg loss: 0.079784
#
# Epoch 62
# -------------------------------
# loss: 0.064531  [    0/ 8760]
# Test Error:
#  MAPE: 4.14%, Avg loss: 0.078522
#
# Epoch 63
# -------------------------------
# loss: 0.069394  [    0/ 8760]
# Test Error:
#  MAPE: 4.01%, Avg loss: 0.075328
#
# Epoch 64
# -------------------------------
# loss: 0.059513  [    0/ 8760]
# Test Error:
#  MAPE: 4.20%, Avg loss: 0.080667
#
# Epoch 65
# -------------------------------
# loss: 0.058207  [    0/ 8760]
# Test Error:
#  MAPE: 4.58%, Avg loss: 0.087478
#
# Epoch 66
# -------------------------------
# loss: 0.059776  [    0/ 8760]
# Test Error:
#  MAPE: 4.07%, Avg loss: 0.076520
#
# Epoch 67
# -------------------------------
# loss: 0.057496  [    0/ 8760]
# Test Error:
#  MAPE: 4.07%, Avg loss: 0.078942
#
# Epoch 68
# -------------------------------
# loss: 0.066346  [    0/ 8760]
# Test Error:
#  MAPE: 4.10%, Avg loss: 0.080112
#
# Epoch 69
# -------------------------------
# loss: 0.063060  [    0/ 8760]
# Test Error:
#  MAPE: 4.05%, Avg loss: 0.075325
#
# Epoch 70
# -------------------------------
# loss: 0.059954  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.073159
#
# Epoch 71
# -------------------------------
# loss: 0.065040  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.072493
#
# Epoch 72
# -------------------------------
# loss: 0.067027  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.071747
#
# Epoch 73
# -------------------------------
# loss: 0.069788  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.075023
#
# Epoch 74
# -------------------------------
# loss: 0.062622  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.074008
#
# Epoch 75
# -------------------------------
# loss: 0.054502  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.073399
#
# Epoch 76
# -------------------------------
# loss: 0.076083  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.072623
#
# Epoch 77
# -------------------------------
# loss: 0.055290  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.072284
#
# Epoch 78
# -------------------------------
# loss: 0.060307  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.073810
#
# Epoch 79
# -------------------------------
# loss: 0.056679  [    0/ 8760]
# Test Error:
#  MAPE: 4.15%, Avg loss: 0.080009
#
# Epoch 80
# -------------------------------
# loss: 0.071750  [    0/ 8760]
# Test Error:
#  MAPE: 4.01%, Avg loss: 0.074997
#
# Epoch 81
# -------------------------------
# loss: 0.056897  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.071718
#
# Epoch 82
# -------------------------------
# loss: 0.058206  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.075790
#
# Epoch 83
# -------------------------------
# loss: 0.061343  [    0/ 8760]
# Test Error:
#  MAPE: 3.93%, Avg loss: 0.075516
#
# Epoch 84
# -------------------------------
# loss: 0.081244  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.072746
#
# Epoch 85
# -------------------------------
# loss: 0.062097  [    0/ 8760]
# Test Error:
#  MAPE: 4.22%, Avg loss: 0.080444
#
# Epoch 86
# -------------------------------
# loss: 0.066644  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.073273
#
# Epoch 87
# -------------------------------
# loss: 0.060376  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.072267
#
# Epoch 88
# -------------------------------
# loss: 0.064760  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.075854
#
# Epoch 89
# -------------------------------
# loss: 0.058083  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.076567
#
# Epoch 90
# -------------------------------
# loss: 0.059632  [    0/ 8760]
# Test Error:
#  MAPE: 4.14%, Avg loss: 0.078531
#
# Epoch 91
# -------------------------------
# loss: 0.063381  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.072808
#
# Epoch 92
# -------------------------------
# loss: 0.060356  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.075907
#
# Epoch 93
# -------------------------------
# loss: 0.053611  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.070469
#
# Epoch 94
# -------------------------------
# loss: 0.061749  [    0/ 8760]
# Test Error:
#  MAPE: 4.12%, Avg loss: 0.077269
#
# Epoch 95
# -------------------------------
# loss: 0.062785  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.075308
#
# Epoch 96
# -------------------------------
# loss: 0.064181  [    0/ 8760]
# Test Error:
#  MAPE: 4.09%, Avg loss: 0.078723
#
# Epoch 97
# -------------------------------
# loss: 0.063579  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.075977
#
# Epoch 98
# -------------------------------
# loss: 0.064474  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.073249
#
# Epoch 99
# -------------------------------
# loss: 0.064065  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.076777
#
# Epoch 100
# -------------------------------
# loss: 0.063129  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.077375
#
# Epoch 101
# -------------------------------
# loss: 0.056014  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.070641
#
# Epoch 102
# -------------------------------
# loss: 0.076301  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.072449
#
# Epoch 103
# -------------------------------
# loss: 0.057412  [    0/ 8760]
# Test Error:
#  MAPE: 4.03%, Avg loss: 0.073184
#
# Epoch 104
# -------------------------------
# loss: 0.058669  [    0/ 8760]
# Test Error:
#  MAPE: 3.93%, Avg loss: 0.074833
#
# Epoch 105
# -------------------------------
# loss: 0.064815  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.071811
#
# Epoch 106
# -------------------------------
# loss: 0.051927  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.076557
#
# Epoch 107
# -------------------------------
# loss: 0.056443  [    0/ 8760]
# Test Error:
#  MAPE: 3.99%, Avg loss: 0.079820
#
# Epoch 108
# -------------------------------
# loss: 0.060423  [    0/ 8760]
# Test Error:
#  MAPE: 3.90%, Avg loss: 0.077002
#
# Epoch 109
# -------------------------------
# loss: 0.060128  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.070099
#
# Epoch 110
# -------------------------------
# loss: 0.052428  [    0/ 8760]
# Test Error:
#  MAPE: 4.13%, Avg loss: 0.077375
#
# Epoch 111
# -------------------------------
# loss: 0.053752  [    0/ 8760]
# Test Error:
#  MAPE: 4.25%, Avg loss: 0.081073
#
# Epoch 112
# -------------------------------
# loss: 0.061723  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.074803
#
# Epoch 113
# -------------------------------
# loss: 0.080088  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.073619
#
# Epoch 114
# -------------------------------
# loss: 0.050933  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.071861
#
# Epoch 115
# -------------------------------
# loss: 0.055046  [    0/ 8760]
# Test Error:
#  MAPE: 3.99%, Avg loss: 0.074178
#
# Epoch 116
# -------------------------------
# loss: 0.059759  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.073454
#
# Epoch 117
# -------------------------------
# loss: 0.052824  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.072872
#
# Epoch 118
# -------------------------------
# loss: 0.052711  [    0/ 8760]
# Test Error:
#  MAPE: 3.71%, Avg loss: 0.069380
#
# Epoch 119
# -------------------------------
# loss: 0.056182  [    0/ 8760]
# Test Error:
#  MAPE: 3.77%, Avg loss: 0.070249
#
# Epoch 120
# -------------------------------
# loss: 0.052923  [    0/ 8760]
# Test Error:
#  MAPE: 3.70%, Avg loss: 0.071159
#
# Epoch 121
# -------------------------------
# loss: 0.058117  [    0/ 8760]
# Test Error:
#  MAPE: 3.71%, Avg loss: 0.069171
#
# Epoch 122
# -------------------------------
# loss: 0.056961  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.072646
#
# Epoch 123
# -------------------------------
# loss: 0.052667  [    0/ 8760]
# Test Error:
#  MAPE: 3.75%, Avg loss: 0.069989
#
# Epoch 124
# -------------------------------
# loss: 0.053092  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.073629
#
# Epoch 125
# -------------------------------
# loss: 0.056952  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.074776
#
# Epoch 126
# -------------------------------
# loss: 0.051819  [    0/ 8760]
# Test Error:
#  MAPE: 3.93%, Avg loss: 0.074725
#
# Epoch 127
# -------------------------------
# loss: 0.058197  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.069732
#
# Epoch 128
# -------------------------------
# loss: 0.062992  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.073059
#
# Epoch 129
# -------------------------------
# loss: 0.066585  [    0/ 8760]
# Test Error:
#  MAPE: 3.78%, Avg loss: 0.070829
#
# Epoch 130
# -------------------------------
# loss: 0.051804  [    0/ 8760]
# Test Error:
#  MAPE: 4.52%, Avg loss: 0.088821
#
# Epoch 131
# -------------------------------
# loss: 0.059845  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.072690
#
# Epoch 132
# -------------------------------
# loss: 0.056102  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.071562
#
# Epoch 133
# -------------------------------
# loss: 0.055668  [    0/ 8760]
# Test Error:
#  MAPE: 3.88%, Avg loss: 0.073516
#
# Epoch 134
# -------------------------------
# loss: 0.073321  [    0/ 8760]
# Test Error:
#  MAPE: 3.95%, Avg loss: 0.077343
#
# Epoch 135
# -------------------------------
# loss: 0.047325  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.073431
#
# Epoch 136
# -------------------------------
# loss: 0.056457  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.073896
#
# Epoch 137
# -------------------------------
# loss: 0.049944  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.076992
#
# Epoch 138
# -------------------------------
# loss: 0.053011  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.074387
#
# Epoch 139
# -------------------------------
# loss: 0.050497  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.074775
#
# Epoch 140
# -------------------------------
# loss: 0.058965  [    0/ 8760]
# Test Error:
#  MAPE: 3.76%, Avg loss: 0.070006
#
# Epoch 141
# -------------------------------
# loss: 0.066204  [    0/ 8760]
# Test Error:
#  MAPE: 3.92%, Avg loss: 0.074040
#
# Epoch 142
# -------------------------------
# loss: 0.060116  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.073357
#
# Epoch 143
# -------------------------------
# loss: 0.053660  [    0/ 8760]
# Test Error:
#  MAPE: 3.78%, Avg loss: 0.072099
#
# Epoch 144
# -------------------------------
# loss: 0.057843  [    0/ 8760]
# Test Error:
#  MAPE: 3.75%, Avg loss: 0.073078
#
# Epoch 145
# -------------------------------
# loss: 0.051238  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.072923
#
# Epoch 146
# -------------------------------
# loss: 0.052985  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.078047
#
# Epoch 147
# -------------------------------
# loss: 0.054291  [    0/ 8760]
# Test Error:
#  MAPE: 3.93%, Avg loss: 0.075150
#
# Epoch 148
# -------------------------------
# loss: 0.058197  [    0/ 8760]
# Test Error:
#  MAPE: 3.90%, Avg loss: 0.076283
#
# Epoch 149
# -------------------------------
# loss: 0.053481  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.074134
#
# Epoch 150
# -------------------------------
# loss: 0.053094  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.074172
#
# Epoch 151
# -------------------------------
# loss: 0.049737  [    0/ 8760]
# Test Error:
#  MAPE: 3.72%, Avg loss: 0.069679
#
# Epoch 152
# -------------------------------
# loss: 0.064052  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.075044
#
# Epoch 153
# -------------------------------
# loss: 0.046505  [    0/ 8760]
# Test Error:
#  MAPE: 3.90%, Avg loss: 0.075528
#
# Epoch 154
# -------------------------------
# loss: 0.054769  [    0/ 8760]
# Test Error:
#  MAPE: 3.79%, Avg loss: 0.073653
#
# Epoch 155
# -------------------------------
# loss: 0.048803  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.077599
#
# Epoch 156
# -------------------------------
# loss: 0.054199  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.070955
#
# Epoch 157
# -------------------------------
# loss: 0.052028  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.073819
#
# Epoch 158
# -------------------------------
# loss: 0.046155  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.073158
#
# Epoch 159
# -------------------------------
# loss: 0.048220  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.073128
#
# Epoch 160
# -------------------------------
# loss: 0.058885  [    0/ 8760]
# Test Error:
#  MAPE: 3.94%, Avg loss: 0.076206
#
# Epoch 161
# -------------------------------
# loss: 0.062466  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.071173
#
# Epoch 162
# -------------------------------
# loss: 0.058246  [    0/ 8760]
# Test Error:
#  MAPE: 3.74%, Avg loss: 0.072100
#
# Epoch 163
# -------------------------------
# loss: 0.057859  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.073482
#
# Epoch 164
# -------------------------------
# loss: 0.049200  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.074813
#
# Epoch 165
# -------------------------------
# loss: 0.054838  [    0/ 8760]
# Test Error:
#  MAPE: 3.77%, Avg loss: 0.073377
#
# Epoch 166
# -------------------------------
# loss: 0.050963  [    0/ 8760]
# Test Error:
#  MAPE: 3.69%, Avg loss: 0.068823
#
# Epoch 167
# -------------------------------
# loss: 0.053754  [    0/ 8760]
# Test Error:
#  MAPE: 3.71%, Avg loss: 0.069567
#
# Epoch 168
# -------------------------------
# loss: 0.043876  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.075431
#
# Epoch 169
# -------------------------------
# loss: 0.063850  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.073550
#
# Epoch 170
# -------------------------------
# loss: 0.052487  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.075964
#
# Epoch 171
# -------------------------------
# loss: 0.052500  [    0/ 8760]
# Test Error:
#  MAPE: 3.73%, Avg loss: 0.070390
#
# Epoch 172
# -------------------------------
# loss: 0.055141  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.074208
#
# Epoch 173
# -------------------------------
# loss: 0.056873  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.072659
#
# Epoch 174
# -------------------------------
# loss: 0.046976  [    0/ 8760]
# Test Error:
#  MAPE: 3.77%, Avg loss: 0.071142
#
# Epoch 175
# -------------------------------
# loss: 0.056345  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.075259
#
# Epoch 176
# -------------------------------
# loss: 0.045544  [    0/ 8760]
# Test Error:
#  MAPE: 3.76%, Avg loss: 0.070715
#
# Epoch 177
# -------------------------------
# loss: 0.051616  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.074092
#
# Epoch 178
# -------------------------------
# loss: 0.059312  [    0/ 8760]
# Test Error:
#  MAPE: 3.80%, Avg loss: 0.071417
#
# Epoch 179
# -------------------------------
# loss: 0.050294  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.073539
#
# Epoch 180
# -------------------------------
# loss: 0.046214  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.075504
#
# Epoch 181
# -------------------------------
# loss: 0.050007  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.077439
#
# Epoch 182
# -------------------------------
# loss: 0.051649  [    0/ 8760]
# Test Error:
#  MAPE: 3.87%, Avg loss: 0.075069
#
# Epoch 183
# -------------------------------
# loss: 0.049116  [    0/ 8760]
# Test Error:
#  MAPE: 3.78%, Avg loss: 0.073349
#
# Epoch 184
# -------------------------------
# loss: 0.049950  [    0/ 8760]
# Test Error:
#  MAPE: 3.82%, Avg loss: 0.074062
#
# Epoch 185
# -------------------------------
# loss: 0.060794  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.072559
#
# Epoch 186
# -------------------------------
# loss: 0.056482  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.077558
#
# Epoch 187
# -------------------------------
# loss: 0.048020  [    0/ 8760]
# Test Error:
#  MAPE: 3.93%, Avg loss: 0.077652
#
# Epoch 188
# -------------------------------
# loss: 0.060252  [    0/ 8760]
# Test Error:
#  MAPE: 3.96%, Avg loss: 0.077596
#
# Epoch 189
# -------------------------------
# loss: 0.068306  [    0/ 8760]
# Test Error:
#  MAPE: 3.89%, Avg loss: 0.075976
#
# Epoch 190
# -------------------------------
# loss: 0.053445  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.075842
#
# Epoch 191
# -------------------------------
# loss: 0.053704  [    0/ 8760]
# Test Error:
#  MAPE: 3.86%, Avg loss: 0.078152
#
# Epoch 192
# -------------------------------
# loss: 0.045379  [    0/ 8760]
# Test Error:
#  MAPE: 3.91%, Avg loss: 0.078397
#
# Epoch 193
# -------------------------------
# loss: 0.052236  [    0/ 8760]
# Test Error:
#  MAPE: 3.78%, Avg loss: 0.073006
#
# Epoch 194
# -------------------------------
# loss: 0.048196  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.077501
#
# Epoch 195
# -------------------------------
# loss: 0.049884  [    0/ 8760]
# Test Error:
#  MAPE: 3.83%, Avg loss: 0.074549
#
# Epoch 196
# -------------------------------
# loss: 0.047395  [    0/ 8760]
# Test Error:
#  MAPE: 3.85%, Avg loss: 0.075378
#
# Epoch 197
# -------------------------------
# loss: 0.058995  [    0/ 8760]
# Test Error:
#  MAPE: 3.84%, Avg loss: 0.076147
#
# Epoch 198
# -------------------------------
# loss: 0.048826  [    0/ 8760]
# Test Error:
#  MAPE: 3.81%, Avg loss: 0.073314
#
# Epoch 199
# -------------------------------
# loss: 0.046476  [    0/ 8760]
# Test Error:
#  MAPE: 3.97%, Avg loss: 0.079630
#
# Epoch 200
# -------------------------------
# loss: 0.051586  [    0/ 8760]
# Test Error:
#  MAPE: 3.98%, Avg loss: 0.079312
#
# Done!

# %%
# %%shell
# jupyter nbconvert --to html /content/hw6_slee93.ipynb
# Out:
# [NbConvertApp] WARNING | pattern '/content/hw6_slee93.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# =======
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
#     Equivalent to: [--JupyterApp.answer_yes=True]
# --execute
#     Execute the notebook prior to export.
#     Equivalent to: [--ExecutePreprocessor.enabled=True]
# --allow-errors
#     Continue notebook execution even if one of the cells throws an error and include the error message in the cell output (the default behaviour is to abort conversion). This flag is only relevant if '--execute' was specified, too.
#     Equivalent to: [--ExecutePreprocessor.allow_errors=True]
# --stdin
#     read a single notebook file from stdin. Write the resulting notebook with default basename 'notebook.*'
#     Equivalent to: [--NbConvertApp.from_stdin=True]
# --stdout
#     Write notebook output to stdout instead of files.
#     Equivalent to: [--NbConvertApp.writer_class=StdoutWriter]
# --inplace
#     Run nbconvert in place, overwriting the existing notebook (only
#             relevant when converting to notebook format)
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory=]
# --clear-output
#     Clear output of current file and save in place,
#             overwriting the existing notebook.
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory= --ClearOutputPreprocessor.enabled=True]
# --coalesce-streams
#     Coalesce consecutive stdout and stderr outputs into one stream (within each cell).
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory= --CoalesceStreamsPreprocessor.enabled=True]
# --no-prompt
#     Exclude input and output prompts from converted document.
#     Equivalent to: [--TemplateExporter.exclude_input_prompt=True --TemplateExporter.exclude_output_prompt=True]
# --no-input
#     Exclude input cells and output prompts from converted document.
#             This mode is ideal for generating code-free reports.
#     Equivalent to: [--TemplateExporter.exclude_output_prompt=True --TemplateExporter.exclude_input=True --TemplateExporter.exclude_input_prompt=True]
# --allow-chromium-download
#     Whether to allow downloading chromium if no suitable version is found on the system.
#     Equivalent to: [--WebPDFExporter.allow_chromium_download=True]
# --disable-chromium-sandbox
#     Disable chromium security sandbox when converting to PDF..
#     Equivalent to: [--WebPDFExporter.disable_sandbox=True]
# --show-input
#     Shows code input. This flag is only useful for dejavu users.
#     Equivalent to: [--TemplateExporter.exclude_input=False]
# --embed-images
#     Embed the images as base64 dataurls in the output. This flag is only useful for the HTML/WebPDF/Slides exports.
#     Equivalent to: [--HTMLExporter.embed_images=True]
# --sanitize-html
#     Whether the HTML in Markdown cells and cell outputs should be sanitized..
#     Equivalent to: [--HTMLExporter.sanitize_html=True]
# --log-level=<Enum>
#     Set the log level by value or name.
#     Choices: any of [0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL']
#     Default: 30
#     Equivalent to: [--Application.log_level]
# --config=<Unicode>
#     Full path of a config file.
#     Default: ''
#     Equivalent to: [--JupyterApp.config_file]
# --to=<Unicode>
#     The export format to be used, either one of the built-in formats
#             ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'qtpdf', 'qtpng', 'rst', 'script', 'slides', 'webpdf']
#             or a dotted object name that represents the import path for an
#             ``Exporter`` class
#     Default: ''
#     Equivalent to: [--NbConvertApp.export_format]
# --template=<Unicode>
#     Name of the template to use
#     Default: ''
#     Equivalent to: [--TemplateExporter.template_name]
# --template-file=<Unicode>
#     Name of the template file to use
#     Default: None
#     Equivalent to: [--TemplateExporter.template_file]
# --theme=<Unicode>
#     Template specific theme(e.g. the name of a JupyterLab CSS theme distributed
#     as prebuilt extension for the lab template)
#     Default: 'light'
#     Equivalent to: [--HTMLExporter.theme]
# --sanitize_html=<Bool>
#     Whether the HTML in Markdown cells and cell outputs should be sanitized.This
#     should be set to True by nbviewer or similar tools.
#     Default: False
#     Equivalent to: [--HTMLExporter.sanitize_html]
# --writer=<DottedObjectName>
#     Writer class used to write the
#                                         results of the conversion
#     Default: 'FilesWriter'
#     Equivalent to: [--NbConvertApp.writer_class]
# --post=<DottedOrNone>
#     PostProcessor class used to write the
#                                         results of the conversion
#     Default: ''
#     Equivalent to: [--NbConvertApp.postprocessor_class]
# --output=<Unicode>
#     Overwrite base name use for output files.
#                 Supports pattern replacements '{notebook_name}'.
#     Default: '{notebook_name}'
#     Equivalent to: [--NbConvertApp.output_base]
# --output-dir=<Unicode>
#     Directory to write output(s) to. Defaults
#                                   to output to the directory of each notebook. To recover
#                                   previous default behaviour (outputting to the current
#                                   working directory) use . as the flag value.
#     Default: ''
#     Equivalent to: [--FilesWriter.build_directory]
# --reveal-prefix=<Unicode>
#     The URL prefix for reveal.js (version 3.x).
#             This defaults to the reveal CDN, but can be any url pointing to a copy
#             of reveal.js.
#             For speaker notes to work, this must be a relative path to a local
#             copy of reveal.js: e.g., "reveal.js".
#             If a relative path is given, it must be a subdirectory of the
#             current directory (from which the server is run).
#             See the usage documentation
#             (https://nbconvert.readthedocs.io/en/latest/usage.html#reveal-js-html-slideshow)
#             for more details.
#     Default: ''
#     Equivalent to: [--SlidesExporter.reveal_url_prefix]
# --nbformat=<Enum>
#     The nbformat version to write.
#             Use this to downgrade notebooks.
#     Choices: any of [1, 2, 3, 4]
#     Default: 4
#     Equivalent to: [--NotebookExporter.nbformat_version]
#
# Examples
# --------
#
#     The simplest way to use nbconvert is
#
#             > jupyter nbconvert mynotebook.ipynb --to html
#
#             Options include ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'qtpdf', 'qtpng', 'rst', 'script', 'slides', 'webpdf'].
#
#             > jupyter nbconvert --to latex mynotebook.ipynb
#
#             Both HTML and LaTeX support multiple output templates. LaTeX includes
#             'base', 'article' and 'report'.  HTML includes 'basic', 'lab' and
#             'classic'. You can specify the flavor of the format used.
#
#             > jupyter nbconvert --to html --template lab mynotebook.ipynb
#
#             You can also pipe the output to stdout, rather than a file
#
#             > jupyter nbconvert mynotebook.ipynb --stdout
#
#             PDF is generated via latex
#
#             > jupyter nbconvert mynotebook.ipynb --to pdf
#
#             You can get (and serve) a Reveal.js-powered slideshow
#
#             > jupyter nbconvert myslides.ipynb --to slides --post serve
#
#             Multiple notebooks can be given at the command line in a couple of
#             different ways:
#
#             > jupyter nbconvert notebook*.ipynb
#             > jupyter nbconvert notebook1.ipynb notebook2.ipynb
#
#             or you can specify the notebooks list in a config file, containing::
#
#                 c.NbConvertApp.notebooks = ["my_notebook.ipynb"]
#
#             > jupyter nbconvert --config mycfg.py
#
# To see all available configurables, use `--help-all`.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-5-e6ed33b28cd1> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('shell', '', 'jupyter nbconvert --to html /content/hw6_slee93.ipynb\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _shell_cell_magic(args, cmd)
#     110   result = _run_command(cmd, clear_streamed_output=False)
#     111   if not parsed_args.ignore_errors:
# --> 112     result.check_returncode()
#     113   return result
#     114
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in check_returncode(self)
#     135   def check_returncode(self):
#     136     if self.returncode:
# --> 137       raise subprocess.CalledProcessError(
#     138           returncode=self.returncode, cmd=self.args, output=self.output
#     139       )
#
# CalledProcessError: Command 'jupyter nbconvert --to html /content/hw6_slee93.ipynb
# ' returned non-zero exit status 255.
